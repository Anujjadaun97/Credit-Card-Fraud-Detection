# %% [markdown]
# TASK TO DO
#
# 1- Credit card data
#
# 2- Data Processing
#
# 3- Data Analysis
#
# 4- Train Test Split
#
# 5- Logistic Regression Model
#
# 6- Model Evaluation

# %% [markdown]
# IMPORTING THE DEPENDENCIES

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#loading the dataset
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
#data info
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186284 entries, 0 to 186283
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    186284 non-null  float64
#  1   V1      186284 non-null  float64
#  2   V2      186284 non-null  float64
#  3   V3      186284 non-null  float64
#  4   V4      186284 non-null  float64
#  5   V5      186284 non-null  float64
#  6   V6      186284 non-null  float64
#  7   V7      186284 non-null  float64
#  8   V8      186284 non-null  float64
#  9   V9      186284 non-null  float64
#  10  V10     186284 non-null  float64
#  11  V11     186284 non-null  float64
#  12  V12     186284 non-null  float64
#  13  V13     186284 non-null  float64
#  14  V14     186284 non-null  float64
#  15  V15     186284 non-null  float64
#  16  V16     186284 non-null  float64
#  17  V17     186284 non-null  float64
#  18  V18     186284 non-null  float64
#  19  V19     186284 non-null  float64
#  20  V20     186284 non-null  float64
#  21  V21     186284 non-null  float64
#  22  V22     186284 non-null  float64
#  23  V23     186284 non-null  float64
#  24  V24     186284 non-null  float64
#  25  V25     186284 non-null  float64
#  26  V26     186283 non-null  float64
#  27  V27     186283 non-null  float64
#  28  V28     186283 non-null  float64
#  29  Amount  186283 non-null  float64
#  30  Class   186283 non-null  float64
# dtypes: float64(31)
# memory usage: 44.1 MB

# %%
#checking null
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
credit_card_data.dropna(inplace=True)

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#distribution of legit transactions & fraudulent transactions
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    185915
# 1.0       368
# Name: count, dtype: int64

# %% [markdown]
# This Datadet is highly unbalanced

# %% [markdown]
# 0--> Normal Transaction
#
# 1--> Fraudulent Transction

# %%
# separating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
legit.shape, fraud.shape
# Out:
# ((185915, 31), (368, 31))

# %%
legit.Amount.describe()
# Out:
# count    185915.000000
# mean         88.756587
# std         247.337401
# min           0.000000
# 25%           5.930000
# 50%          22.690000
# 75%          78.540000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     368.000000
# mean      115.659891
# std       248.444604
# min         0.000000
# 25%         1.000000
# 50%        11.395000
# 75%       104.007500
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    66284.638657 -0.120016  0.008639  0.410317  0.081403 -0.132662
# 1.0    58116.711957 -5.926741  4.330987 -7.884388  4.836685 -4.286202
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.055453 -0.050609  0.022313  0.018967  ...  0.023936 -0.021210
# 1.0   -1.424070 -6.893932  0.739547 -2.838131  ...  0.404833  0.790022
#
#            V22      V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.06309 -0.01857  0.006409  0.074405  0.009086  0.001497  0.002095
# 1.0   -0.02306 -0.04394 -0.071941  0.080214  0.040915  0.177371  0.050569
#
#            Amount
# Class
# 0.0     88.756587
# 1.0    115.659891
#
# [2 rows x 30 columns]

# %% [markdown]
# Under Sampling

# %% [markdown]
# Build a sample dataset containing similar distribution of normal transactions and Fraudulent Transactions

# %%
legit_sample = legit.sample(n=368)

# %% [markdown]
# Concatenating two DataFrames

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 184351  126209.0  1.968614  0.054627 -1.751636  0.576864  0.086761 -1.520067
# 71400    54284.0 -0.694485  0.318627  0.599946  0.662637 -0.718827 -0.253834
# 89697    62688.0  1.083584 -0.207771 -0.466833 -0.071923  0.090746 -0.412549
# 149626   91602.0  2.090343  0.598046 -1.838012  1.289488  1.130558 -0.841521
# 182343  125357.0  1.620796 -0.462045 -2.646144  0.694921  0.636105 -0.368740
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 184351  0.320705 -0.396683  0.617392  ...  0.221287  0.701682 -0.056870
# 71400   0.533570  0.232272 -1.998113  ... -0.035956  0.223287  0.384867
# 89697   0.347909 -0.097215 -0.350657  ...  0.060940 -0.021220 -0.186429
# 149626  0.762916 -0.577610  0.890544  ... -0.021141  0.354441  0.008325
# 182343  0.372133 -0.063660  0.737354  ... -0.050084 -0.431510 -0.148671
#
#              V24       V25       V26       V27       V28  Amount  Class
# 184351 -0.020900  0.228185 -0.108150 -0.012333 -0.023560   48.95    0.0
# 71400   0.396643 -0.543134 -0.324144  0.094776  0.126808  144.32    0.0
# 89697  -0.235437  0.447738  1.094945 -0.120614 -0.010887   98.35    0.0
# 149626  0.583350  0.525496 -0.551058 -0.049974 -0.061675    2.00    0.0
# 182343  0.001130  0.135403 -0.333669 -0.037107  0.019314  215.74    0.0
#
# [5 rows x 31 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    368
# 1.0    368
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    67348.089674 -0.082499 -0.115144  0.351413  0.173189 -0.111981
# 1.0    58116.711957 -5.926741  4.330987 -7.884388  4.836685 -4.286202
#
#             V6        V7        V8        V9  ...       V20       V21  \
# Class                                         ...
# 0.0    0.15033 -0.136208 -0.071428  0.085067  ...  0.045211 -0.111557
# 1.0   -1.42407 -6.893932  0.739547 -2.838131  ...  0.404833  0.790022
#
#             V22      V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.026881  0.01110 -0.007828  0.118717 -0.039185 -0.025153  0.002274
# 1.0   -0.023060 -0.04394 -0.071941  0.080214  0.040915  0.177371  0.050569
#
#            Amount
# Class
# 0.0     93.516440
# 1.0    115.659891
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting data into Features and Targets

# %%
x = new_dataset.drop(columns='Class', axis=1)
y = new_dataset['Class']

# %%
x.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 184351  126209.0  1.968614  0.054627 -1.751636  0.576864  0.086761 -1.520067
# 71400    54284.0 -0.694485  0.318627  0.599946  0.662637 -0.718827 -0.253834
# 89697    62688.0  1.083584 -0.207771 -0.466833 -0.071923  0.090746 -0.412549
# 149626   91602.0  2.090343  0.598046 -1.838012  1.289488  1.130558 -0.841521
# 182343  125357.0  1.620796 -0.462045 -2.646144  0.694921  0.636105 -0.368740
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 184351  0.320705 -0.396683  0.617392  ... -0.127782  0.221287  0.701682
# 71400   0.533570  0.232272 -1.998113  ... -0.183784 -0.035956  0.223287
# 89697   0.347909 -0.097215 -0.350657  ...  0.077980  0.060940 -0.021220
# 149626  0.762916 -0.577610  0.890544  ... -0.206226 -0.021141  0.354441
# 182343  0.372133 -0.063660  0.737354  ...  0.230256 -0.050084 -0.431510
#
#              V23       V24       V25       V26       V27       V28  Amount
# 184351 -0.056870 -0.020900  0.228185 -0.108150 -0.012333 -0.023560   48.95
# 71400   0.384867  0.396643 -0.543134 -0.324144  0.094776  0.126808  144.32
# 89697  -0.186429 -0.235437  0.447738  1.094945 -0.120614 -0.010887   98.35
# 149626  0.008325  0.583350  0.525496 -0.551058 -0.049974 -0.061675    2.00
# 182343 -0.148671  0.001130  0.135403 -0.333669 -0.037107  0.019314  215.74
#
# [5 rows x 30 columns]

# %%
y.head()
# Out:
# 184351    0.0
# 71400     0.0
# 89697     0.0
# 149626    0.0
# 182343    0.0
# Name: Class, dtype: float64

# %% [markdown]
# Splitting data into Training data & Testing data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=2)

# %%
x.shape, x_train.shape, x_test.shape
# Out:
# ((736, 30), (588, 30), (148, 30))

# %% [markdown]
# Model Training
#
# Logistic Regression

# %%
model = LogisticRegression()

# %%
# tranining the Logistic Regression Model with Training Data
model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model Evaluation
#
# Accuracy score

# %%
# accuracy on training data
x_train_prediction = model.predict(x_train)
training_data_accuracy = accuracy_score(x_train_prediction, y_train)

# %%
training_data_accuracy
# Out:
# 0.9438775510204082

# %%
# accuracy on test data score
x_test_prediction = model.predict(x_test)
testing_data_accuracy = accuracy_score(x_test_prediction, y_test)

# %%
testing_data_accuracy
# Out:
# 0.9527027027027027
